# %% [markdown]
# https://www.youtube.com/watch?v=kx2GzBeGPco

# %%
from sympy import *
init_printing()
x, y, z, u, v = symbols('x y z u v')
alpha1, beta, omega_21 = symbols('alpha1 beta omega_2_1')
x, y, z, alpha1, beta, omega_21
# Out:
# (x, y, z, α₁, β, ω₂ ₁)

# %%
#oef 8 reeks2
#voor l heb je
x=u
y=-3+u
z=6
#bol vergelijking om zetten
B=((x-1)**2)+((y+2)**2)+((z-3)**2)-9

# %%
# Parametervoorstellingen van de rechte l
x_l = u + 3
y_l = u
z_l = 6

# Vergelijking van de bol: (x - 1)^2 + (y + 2)^2 + (z - 3)^2 = 9

# Bolvergelijking: substitueer de parametervoorstellingen van de rechte
bol_vergelijking = (x_l - 1)**2 + (y_l + 2)**2 + (z_l - 3)**2 - 9

# Los de vergelijking op om t te vinden
u_oplossing = solve(bol_vergelijking, u)

# Bepaal de snijpunten A
x_A = x_l.subs(u, u_oplossing[0])
y_A = y_l.subs(u, u_oplossing[0])
z_A = z_l

x_A , y_A ,z_A
# Out:
# (1, -2, 6)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

#Middelpunt en straal van de bol
center = (1, -2, 3)
radius = np.sqrt(9)

#Maak een grid van punten voor de bol
u = np.linspace(0, 2 * np.pi, 100)  # Hoek in de xy-vlak
v = np.linspace(0, np.pi, 100)       # Hoek in de yz-vlak

#Parametriseer de bol
x = center[0] + radius * np.outer(np.cos(u), np.sin(v))
y = center[1] + radius * np.outer(np.sin(u), np.sin(v))
z = center[2] + radius * np.outer(np.ones(np.size(u)), np.cos(v))

#Coördinaten van de punten A, B, C en D
points = {
    'A': (1, -2, 6),
    
}
#Maak een 3D-plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

#Plot de bol
ax.plot_surface(x, y, z, color='r', alpha=0.6)  # Kleur en transparantie

#Plot de punt A
for point_name, (px, py, pz) in points.items():
    ax.scatter(px, py, pz, label=point_name, s=100)  # s = grootte van de marker

#Labels en titel
ax.set_xlabel('X-as')
ax.set_ylabel('Y-as')
ax.set_zlabel('Z-as')
ax.set_title('3D Bol met middelpunt (1, -2, 3) en straal √9')

# Plot de rechte l
plot_rechte(ax, u_min=-5, u_max=5)

# Plot het raakvlak z = 6
plot_raakvlak(ax, z_value=6)

#Toon de legenda
ax.legend()

#Toon de plot
plt.show()
